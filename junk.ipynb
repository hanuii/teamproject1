# %%
key = pd.read_csv('key.csv')
train = pd.read_csv('train.csv')
weather = pd.read_csv('weather.csv')

# %%
weather[weather['station_nbr'] == 5]
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 2892             5  2012-06-01    M    M    M      M        M       M    M
# 2912             5  2012-06-02    M    M    M      M        M       M    M
# 2932             5  2012-06-03    M    M    M      M        M       M    M
# 2952             5  2012-06-04    M    M    M      M        M       M    M
# 2972             5  2012-06-05    M    M    M      M        M       M    M
# 2992             5  2012-06-06    M    M    M      M        M       M    M
# 3012             5  2012-06-07    M    M    M      M        M       M    M
# 3032             5  2012-06-08    M    M    M      M        M       M    M
# 3052             5  2012-06-09    M    M    M      M        M       M    M
# 3072             5  2012-06-10    M    M    M      M        M       M    M
# 3092             5  2012-06-11    M    M    M      M        M       M    M
# ...

# %%
weather[weather['station_nbr'] == 1]
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 19               1  2012-01-02   50   31   41      M       26      35   24
# 38               1  2012-01-03   32   11   22      M        4      18   43
# 57               1  2012-01-04   28    9   19      M       -1      14   46
# 76               1  2012-01-05   38   25   32      M       13      25   33
# 95               1  2012-01-06   46   25   36      M       21      29   29
# 114              1  2012-01-07   57   28   43      M       28      36   22
# 133              1  2012-01-08   45   27   36      M       22      32   29
# 152              1  2012-01-09   39   23   31      M       12      25   34
# 171              1  2012-01-10   47   29   38      M       24      32   27
# 190              1  2012-01-11   39   24   32      M       21      29   33
# ...

# %%
key
# Out:
#     store_nbr  station_nbr
# 0           1            1
# 1           2           14
# 2           3            7
# 3           4            9
# 4           5           12
# 5           6           14
# 6           7            6
# 7           8            4
# 8           9           17
# 9          10           12
# 10         11           10
# 11         12           11
# 12         13            6
# 13         14           16
# 14         15           13
# 15         16            2
# 16         17           20
# 17         18           17
# 18         19           15
# 19         20            7
# 20         21            3
# 21         22           10
# 22         23           17
# 23         24            9
# 24         25           13
# 25         26           17
# 26         27           10
# 27         28            7
# 28         29            3
# 29         30           19
# 30         31           17
# 31         32           13
# 32         33            3
# ...

# %%
train_store1 = train[train['store_nbr'] == 1]
train_store1[train_store1['date'] == '2012-01-01']['units'][30:81]
# train_store1['units']
# Out:
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    0
# 36    0
# 37    0
# 38    0
# 39    0
# 40    0
# 41    0
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# 50    1
# 51    0
# 52    0
# 53    0
# 54    0
# 55    0
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# 61    0
# 62    0
# 63    0
# 64    0
# 65    0
# 66    0
# 67    0
# 68    0
# 69    0
# 70    0
# 71    0
# 72    0
# 73    0
# 74    0
# 75    0
# 76    0
# 77    0
# 78    0
# 79    0
# 80    0
# Name: units, dtype: int64
